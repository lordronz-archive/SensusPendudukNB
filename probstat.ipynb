# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('responses.csv')
sns.set(style="ticks")
sns.set_context("notebook", font_scale=2)

# %%
data.head()
# Out:
#              Timestamp  Jumlah_saudara  Jumlah_saudara_ayah  \
# 0  16/10/2020 12:12:38               3                    6
# 1  16/10/2020 12:13:01               2                    4
# 2  16/10/2020 12:17:50               2                    7
# 3  16/10/2020 12:17:59               3                    7
# 4  16/10/2020 12:19:02               3                    7
#
#    Jumlah_saudara_ibu  Ekspektasi_jumlah_anak  \
# 0                   6                       1
# 1                   3                       0
# 2                   4                       2
# 3                   8                       2
# 4                   4                       2
#
#    Ekspektasi_jumlah_anak_tidak_mapan
# 0                                   0
# 1                                   0
# 2                                   0
# 3                                   1
# 4                                   2

# %%
data.describe()
# Out:
#        Jumlah_saudara  Jumlah_saudara_ayah  Jumlah_saudara_ibu  \
# count      250.000000           250.000000          250.000000
# mean         3.392000             6.168000            5.772000
# std          2.124238             3.203251            3.122662
# min          1.000000             1.000000            2.000000
# 25%          2.000000             4.000000            3.000000
# 50%          3.000000             6.000000            5.000000
# 75%          4.000000             7.000000            7.000000
# max         15.000000            15.000000           15.000000
#
#        Ekspektasi_jumlah_anak  Ekspektasi_jumlah_anak_tidak_mapan
# count              250.000000                          250.000000
# mean                 3.052000                            1.212000
# std                  2.566641                            1.358838
# min                  0.000000                            0.000000
# 25%                  2.000000                            0.000000
# ...

# %%
print("Pertanyaan\t\t\t\tVarians")
data.var()
# Out:
# Pertanyaan				Varians
# Jumlah_saudara                         4.512386
# Jumlah_saudara_ayah                   10.260819
# Jumlah_saudara_ibu                     9.751020
# Ekspektasi_jumlah_anak                 6.587647
# Ekspektasi_jumlah_anak_tidak_mapan     1.846442
# dtype: float64

# %%
f, ax = plt.subplots(figsize=(18,18))
ax.set_xticks(range(16))
ax.set_yticks(range(0, 86, 5))
plt.xlabel("Jumlah saudara(Diri sendiri termasuk)")
plt.ylabel("Jumlah pemilih")
plt.title("Histogram data jumlah saudara")
sns.histplot(discrete=True, data=data['Jumlah_saudara'], kde=True)
# Out:
# <AxesSubplot:title={'center':'Histogram data jumlah saudara'}, xlabel='Jumlah saudara(Diri sendiri termasuk)', ylabel='Jumlah pemilih'>

# %%
f, ax = plt.subplots(figsize=(18,18))
ax.set_xticks(range(16))
ax.set_yticks(range(0, 86, 5))
plt.xlabel("Jumlah saudara ayah(Diri sendiri termasuk)")
plt.ylabel("Jumlah pemilih")
plt.title("Histogram data jumlah saudara ayah")
sns.histplot(discrete=True, data=data['Jumlah_saudara_ayah'], kde=True)
# Out:
# <AxesSubplot:title={'center':'Histogram data jumlah saudara ayah'}, xlabel='Jumlah saudara ayah(Diri sendiri termasuk)', ylabel='Jumlah pemilih'>

# %%
data.corr()
# Out:
#                                     Jumlah_saudara  Jumlah_saudara_ayah  \
# Jumlah_saudara                            1.000000             0.077044
# Jumlah_saudara_ayah                       0.077044             1.000000
# Jumlah_saudara_ibu                       -0.075472             0.093379
# Ekspektasi_jumlah_anak                   -0.003754            -0.038680
# Ekspektasi_jumlah_anak_tidak_mapan        0.037878            -0.046967
#
#                                     Jumlah_saudara_ibu  \
# Jumlah_saudara                               -0.075472
# Jumlah_saudara_ayah                           0.093379
# Jumlah_saudara_ibu                            1.000000
# Ekspektasi_jumlah_anak                        0.116735
# Ekspektasi_jumlah_anak_tidak_mapan           -0.008439
#
#                                     Ekspektasi_jumlah_anak  \
# Jumlah_saudara                                   -0.003754
# Jumlah_saudara_ayah                              -0.038680
# ...

# %%
f, ax = plt.subplots(figsize=(18,18))
ax.set_xticks(range(16))
ax.set_yticks(range(0, 86, 5))
plt.xlabel("Jumlah saudara ibu(Diri sendiri termasuk)")
plt.ylabel("Jumlah pemilih")
plt.title("Histogram data jumlah saudara ibu")
sns.histplot(discrete=True, data=data['Jumlah_saudara_ibu'], kde=True)
# Out:
# <AxesSubplot:title={'center':'Histogram data jumlah saudara ibu'}, xlabel='Jumlah saudara ibu(Diri sendiri termasuk)', ylabel='Jumlah pemilih'>

# %%
f, ax = plt.subplots(figsize=(18,18))
ax.set_xticks(range(16))
ax.set_yticks(range(0, 86, 5))
plt.xlabel("Ekspektasi jumlah anak")
plt.ylabel("Jumlah pemilih")
plt.title("Histogram data jumlah ekspektasi anak")
sns.histplot(discrete=True, data=data['Ekspektasi_jumlah_anak'], kde=True)
# Out:
# <AxesSubplot:title={'center':'Histogram data jumlah ekspektasi anak'}, xlabel='Ekspektasi jumlah anak', ylabel='Jumlah pemilih'>

# %%
f, ax = plt.subplots(figsize=(18,18))
ax.set_xticks(range(16))
ax.set_yticks(range(0, 86, 5))
plt.xlabel("Ekspektasi jumlah anak saat tidak mapan")
plt.ylabel("Jumlah pemilih")
plt.title("Histogram data jumlah ekspektasi anak saat tidak mapan")
sns.histplot(discrete=True, data=data['Ekspektasi_jumlah_anak_tidak_mapan'], kde=True)
# Out:
# <AxesSubplot:title={'center':'Histogram data jumlah ekspektasi anak saat tidak mapan'}, xlabel='Ekspektasi jumlah anak saat tidak mapan', ylabel='Jumlah pemilih'>

# %%
plt.figure(figsize=(18,18))
plt.title("Heat map korelasi data Pearson's r")
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn')

plt.show()

# %%
f, ax = plt.subplots(figsize=(18,18))
ax.set_xticks(range(16))
ax.set_yticks(range(0, 86, 5))
plt.ylabel("Jumlah pemilih")
sns.histplot(discrete=True, data=data)
# Out:
# <AxesSubplot:ylabel='Jumlah pemilih'>

# %%
f, ax = plt.subplots(figsize=(18,18))
plt.title("Persebaran data")
sns.kdeplot(data=data, fill=True, alpha=.8)
# Out:
# <AxesSubplot:title={'center':'Persebaran data'}, ylabel='Density'>

# %%
f, ax = plt.subplots(figsize=(18,18))
plt.title("Persebaran data, rata-rata, dan stdev pertanyaan 1")
plt.axvline(x=data.Jumlah_saudara.mean(), color='r', linewidth="3", label=f"Mean/Rata-rata({data.Jumlah_saudara.mean()})")
plt.axvline(x=data.Jumlah_saudara.std(), color='y', linewidth="3", label=f"Standar deviasi({data.Jumlah_saudara.std()})")
ax.legend()
sns.kdeplot(data=data["Jumlah_saudara"], fill=True, alpha=.8)
# Out:
# <AxesSubplot:title={'center':'Persebaran data, rata-rata, dan stdev pertanyaan 1'}, xlabel='Jumlah_saudara', ylabel='Density'>

# %%
data.Jumlah_saudara.std()
# Out:
# 2.124237637875922

# %%
f, ax = plt.subplots(figsize=(18,18))
plt.title("Persebaran data, rata-rata, dan stdev pertanyaan 2")
plt.axvline(x=data.Jumlah_saudara_ayah.mean(), color='r', linewidth="3", label=f"Mean/Rata-rata({data.Jumlah_saudara_ayah.mean()})")
plt.axvline(x=data.Jumlah_saudara_ayah.std(), color='y', linewidth="3", label=f"Standar deviasi({data.Jumlah_saudara_ayah.std()})")
ax.legend()
sns.kdeplot(data=data["Jumlah_saudara_ayah"], fill=True, alpha=.8)
# Out:
# <AxesSubplot:title={'center':'Persebaran data, rata-rata, dan stdev pertanyaan 2'}, xlabel='Jumlah_saudara_ayah', ylabel='Density'>

# %%
f, ax = plt.subplots(figsize=(18,18))
plt.title("Persebaran data, rata-rata, dan stdev pertanyaan 3")
plt.axvline(x=data.Jumlah_saudara_ibu.mean(), color='r', linewidth="3", label=f"Mean/Rata-rata({data.Jumlah_saudara_ibu.mean()})")
plt.axvline(x=data.Jumlah_saudara_ibu.std(), color='y', linewidth="3", label=f"Standar deviasi({data.Jumlah_saudara_ibu.std()})")
ax.legend()
sns.kdeplot(data=data["Jumlah_saudara_ibu"], fill=True, alpha=.8)
# Out:
# <AxesSubplot:title={'center':'Persebaran data, rata-rata, dan stdev pertanyaan 3'}, xlabel='Jumlah_saudara_ibu', ylabel='Density'>

# %%
f, ax = plt.subplots(figsize=(18,18))
plt.title("Persebaran data, rata-rata, dan stdev pertanyaan 4")
plt.axvline(x=data.Ekspektasi_jumlah_anak.mean(), color='r', linewidth="3", label=f"Mean/Rata-rata({data.Ekspektasi_jumlah_anak.mean()})")
plt.axvline(x=data.Ekspektasi_jumlah_anak.std(), color='y', linewidth="3", label=f"Standar deviasi({data.Ekspektasi_jumlah_anak.std()})")
ax.legend()
sns.kdeplot(data=data["Ekspektasi_jumlah_anak"], fill=True, alpha=.8)
# Out:
# <AxesSubplot:title={'center':'Persebaran data, rata-rata, dan stdev pertanyaan 4'}, xlabel='Ekspektasi_jumlah_anak', ylabel='Density'>

# %%
f, ax = plt.subplots(figsize=(18,18))
plt.title("Persebaran data, rata-rata, dan stdev pertanyaan 5")
plt.axvline(x=data.Ekspektasi_jumlah_anak_tidak_mapan.mean(), color='r', linewidth="3", label=f"Mean/Rata-rata({data.Ekspektasi_jumlah_anak_tidak_mapan.mean()})")
plt.axvline(x=data.Ekspektasi_jumlah_anak_tidak_mapan.std(), color='y', linewidth="3", label=f"Standar deviasi({data.Ekspektasi_jumlah_anak_tidak_mapan.std()})")
ax.legend()
sns.kdeplot(data=data["Ekspektasi_jumlah_anak_tidak_mapan"], fill=True, alpha=.8)
# Out:
# <AxesSubplot:title={'center':'Persebaran data, rata-rata, dan stdev pertanyaan 5'}, xlabel='Ekspektasi_jumlah_anak_tidak_mapan', ylabel='Density'>

# %%
data.Jumlah_saudara.describe()
# Out:
# count    250.000000
# mean       3.392000
# std        2.124238
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max       15.000000
# Name: Jumlah_saudara, dtype: float64

# %%
data.Jumlah_saudara_ayah.describe()
# Out:
# count    250.000000
# mean       6.168000
# std        3.203251
# min        1.000000
# 25%        4.000000
# 50%        6.000000
# 75%        7.000000
# max       15.000000
# Name: Jumlah_saudara_ayah, dtype: float64

# %%
data.Jumlah_saudara_ibu.describe()
# Out:
# count    250.000000
# mean       5.772000
# std        3.122662
# min        2.000000
# 25%        3.000000
# 50%        5.000000
# 75%        7.000000
# max       15.000000
# Name: Jumlah_saudara_ibu, dtype: float64

# %%
data.Ekspektasi_jumlah_anak.describe()
# Out:
# count    250.000000
# mean       3.052000
# std        2.566641
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        4.000000
# max       14.000000
# Name: Ekspektasi_jumlah_anak, dtype: float64

# %%
data.Ekspektasi_jumlah_anak_tidak_mapan.describe()
# Out:
# count    250.000000
# mean       1.212000
# std        1.358838
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max       12.000000
# Name: Ekspektasi_jumlah_anak_tidak_mapan, dtype: float64

# %%
sumx = 0
sumy = 0
sumxy = 0
sumx2 = 0
sumy2 = 0
for d1, d2 in zip(data["Jumlah_saudara"], data["Jumlah_saudara_ayah"]):
    sumx += d1
    sumy += d2
    sumxy += d1 * d2
    sumx2 += d1 ** 2
    sumy2 += d2 ** 2
print(sumx, sumy, sumxy, sumx2, sumy2, sumx**2, sumy**2)
print(((250 * sumxy)-(sumx*sumy))/((250*sumx2-sumx**2)*(250*sumy2-sumy**2))**0.5)
# Out:
# 848 1542 5361 4000 12066 719104 2377764
# 0.07704364734433257

# %%
data.corr()
# Out:
#                                     Jumlah_saudara  Jumlah_saudara_ayah  \
# Jumlah_saudara                            1.000000             0.077044
# Jumlah_saudara_ayah                       0.077044             1.000000
# Jumlah_saudara_ibu                       -0.075472             0.093379
# Ekspektasi_jumlah_anak                   -0.003754            -0.038680
# Ekspektasi_jumlah_anak_tidak_mapan        0.037878            -0.046967
#
#                                     Jumlah_saudara_ibu  \
# Jumlah_saudara                               -0.075472
# Jumlah_saudara_ayah                           0.093379
# Jumlah_saudara_ibu                            1.000000
# Ekspektasi_jumlah_anak                        0.116735
# Ekspektasi_jumlah_anak_tidak_mapan           -0.008439
#
#                                     Ekspektasi_jumlah_anak  \
# Jumlah_saudara                                   -0.003754
# Jumlah_saudara_ayah                              -0.038680
# ...
